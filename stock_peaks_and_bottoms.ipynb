# %%
import numpy as np
import pandas as pd
from scipy.signal import argrelextrema
from matplotlib import pyplot as plt

import yfinance as yf

# %% [markdown]
# # Load stock info

# %%
# Download stock info
stock_info = yf.download("NVDA", start="2021-01-01", end="2021-08-16")
stock_info
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-31  131.365005  131.509995  129.149994  130.550003  130.475052
# 2021-01-04  131.042496  136.524994  129.625000  131.134995  131.059723
# 2021-01-05  130.997498  134.434998  130.869995  134.047501  133.970551
# 2021-01-06  132.225006  132.449997  125.860001  126.144997  126.072578
# 2021-01-07  129.675003  133.777496  128.865005  133.440002  133.363388
# ...                ...         ...         ...         ...         ...
# 2021-08-09  204.460007  205.080002  201.429993  202.949997  202.949997
# 2021-08-10  203.220001  204.300003  198.350006  199.360001  199.360001
# 2021-08-11  200.429993  200.490005  194.300003  196.990005  196.990005
# 2021-08-12  198.699997  200.289993  196.199997  199.050003  199.050003
# 2021-08-13  199.050003  202.139999  198.509995  201.880005  201.880005
#
#               Volume
# Date
# 2020-12-31  19242400
# 2021-01-04  56064000
# 2021-01-05  32276000
# 2021-01-06  58042400
# 2021-01-07  46148000
# ...              ...
# 2021-08-09  14644300
# 2021-08-10  17923800
# 2021-08-11  18592500
# 2021-08-12  15165200
# 2021-08-13  18282500
#
# [156 rows x 6 columns]

# %%
# Load the data and convert from pandas dataframe to numpy array
stock_close_data = stock_info["Close"]
stock_close_data = stock_close_data.to_numpy()
stock_close_data
# Out:
# array([130.55000305, 131.13499451, 134.04750061, 126.14499664,
#        133.44000244, 132.76750183, 136.21499634, 134.84750366,
#        135.31750488, 132.00250244, 128.59500122, 130.25250244,
#        133.65750122, 138.67500305, 137.125     , 136.53250122,
#        134.35249329, 129.17750549, 130.50999451, 129.89750671,
#        132.36999512, 135.56750488, 135.30499268, 136.64250183,
#        135.91000366, 144.38749695, 142.63250732, 147.64250183,
#        152.50750732, 149.61250305, 153.30250549, 149.05999756,
#        148.28999329, 149.26499939, 143.55749512, 141.41999817,
#        144.99000549, 133.07499695, 137.14500427, 138.41749573,
#        134.0625    , 128.04750061, 123.70249939, 124.61499786,
#        115.93250275, 125.20249939, 124.68250275, 129.93499756,
#        128.55999756, 131.9125061 , 132.9125061 , 133.4125061 ,
#        127.22499847, 128.45750427, 131.86250305, 130.70750427,
#        126.43000031, 125.35250092, 128.39250183, 129.48249817,
#        128.71749878, 133.48249817, 138.11749268, 139.875     ,
#        138.61500549, 141.43499756, 143.16999817, 144.        ,
#        152.08999634, 156.79499817, 152.77000427, 161.37249756,
#        159.125     , 153.61749268, 151.7124939 , 153.60499573,
#        148.50250244, 152.65249634, 154.77999878, 153.81750488,
#        152.76750183, 153.24749756, 150.09500122, 148.36749268,
#        143.51249695, 144.58500671, 145.22999573, 148.12249756,
#        142.65750122, 143.0625    , 137.58500671, 136.65249634,
#        142.42999268, 141.65499878, 140.15750122, 140.65750122,
#        146.125     , 149.91749573, 156.11999512, 156.47749329,
#        157.        , 154.88000488, 162.44500732, 162.64500427,
#        167.78250122, 169.69749451, 175.78250122, 176.19000244,
#        174.57000732, 173.58250427, 174.25      , 178.25250244,
#        180.1875    , 177.88499451, 178.10249329, 186.57249451,
#        186.38749695, 184.27250671, 188.86749268, 190.57249451,
#        192.05499268, 190.30999756, 199.8500061 , 200.26750183,
#        200.0249939 , 202.11999512, 204.86999512, 206.98500061,
#        203.71749878, 199.02749634, 200.50250244, 205.125     ,
#        202.5       , 198.41499329, 189.6625061 , 181.61000061,
#        187.79750061, 186.11999512, 194.1000061 , 195.94000244,
#        195.58000183, 192.94000244, 192.08000183, 195.02999878,
#        196.61999512, 194.99000549, 197.5       , 198.1499939 ,
#        202.74000549, 206.36999512, 203.66000366, 202.94999695,
#        199.36000061, 196.99000549, 199.05000305, 201.88000488])

# %%
# Plot data
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(stock_close_data, label="Closing price", color="slategrey")
plt.legend()
plt.show()

# %% [markdown]
# # Smooth data

# %%
# Smaller N -> More accurate
# Larger N -> More smooth
N = 25
window = np.blackman(N)
smoothed_data = np.convolve(window/window.sum(), stock_close_data, mode='same')

# %%
# Plot data
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(stock_close_data, label="Closing price", color="slategrey")
plt.plot(smoothed_data, label="Smoothed data", color="darkturquoise")
plt.legend()
plt.show()

# %% [markdown]
# # Find local maxima

# %%
# Find local maxima
peaks = argrelextrema(smoothed_data, np.greater)[0]
stock_info.iloc[peaks]["Close"]
# Out:
# Date
# 2021-01-21    138.675003
# 2021-02-16    153.302505
# 2021-04-20    151.712494
# 2021-07-06    206.985001
# 2021-08-02    197.500000
# Name: Close, dtype: float64

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(stock_close_data, label="Closing price", color="slategrey")
plt.plot(smoothed_data, label="Smoothed data", color="darkturquoise")
plt.plot(peaks, stock_close_data[peaks], "x", color="red")
plt.legend()
plt.show()

# %% [markdown]
# # Find local minima

# %%
# Find local minima
bottoms = argrelextrema(smoothed_data, np.less)[0]
stock_info.iloc[bottoms]["Close"]
# Out:
# Date
# 2021-01-25    136.532501
# 2021-03-09    125.202499
# 2021-05-12    137.585007
# 2021-07-21    194.100006
# Name: Close, dtype: float64

# %%
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(stock_close_data, label="Closing price", color="slategrey")
plt.plot(smoothed_data, label="Smoothed data", color="darkturquoise")
plt.plot(bottoms, stock_close_data[bottoms], "x", color="red")
plt.legend()
plt.show()

# %% [markdown]
# # Final result

# %%
# Peaks
stock_info.iloc[peaks]["Close"]
# Out:
# Date
# 2021-01-21    138.675003
# 2021-02-16    153.302505
# 2021-04-20    151.712494
# 2021-07-06    206.985001
# 2021-08-02    197.500000
# Name: Close, dtype: float64

# %%
# Bottoms
stock_info.iloc[bottoms]["Close"]
# Out:
# Date
# 2021-01-25    136.532501
# 2021-03-09    125.202499
# 2021-05-12    137.585007
# 2021-07-21    194.100006
# Name: Close, dtype: float64

# %%
# Plot graph
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(stock_close_data, label="Closing price", color="slategrey")
plt.plot(smoothed_data, label="Smoothed data", color="darkturquoise")
plt.plot(peaks, stock_close_data[peaks], "x", color="green")
plt.plot(bottoms, stock_close_data[bottoms], "x", color="red")
for index, x_coord in enumerate(peaks):
    plt.annotate("{:.2f}".format(stock_close_data[x_coord]), (x_coord, stock_close_data[x_coord]+5))
for index, x_coord in enumerate(bottoms):
    plt.annotate("{:.2f}".format(stock_close_data[x_coord]), (x_coord, stock_close_data[x_coord]-5))
plt.legend()
plt.show()
